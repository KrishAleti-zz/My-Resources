# %% [markdown]
# MongoDB Playlist: https://www.youtube.com/playlist?list=PLZoTAELRMXVN_8zzsevm1bm6G-plsiO1I

# %% [markdown]
# MongoDB supports GeoSpatial Queries

# %% [markdown]
# ### MongoDB in CMD prompt:

# %% [markdown]
# #### Creating DB:
# `use dbname`
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Inserting documents into the Collection:
# `db.collectionname.insertOne({})`
#
# `db.collectionname.insertOne({})` --- When we try to insert document using this command, if the mentioned collection is not present it will created and then the documents will be inserted into it.
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
#
# ![image-4.png](attachment:image-4.png)
# ![image-3.png](attachment:image-3.png)
#
#
# `db.collectionname.insertMany([{}])`
#
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# #### Find
#
# **Finding the 1st record:**
# ![image-2.png](attachment:image-2.png)
# **Finding all records:**
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)
#
# #### Find the records with condition
# having fn1=k1:
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## MongoDB with Python:

# %% [markdown]
# ### Connecting Python to MongoDB Compass

# %%
import pymongo
client =pymongo.MongoClient("mongodb://localhost:27017/")

# %% [markdown]
# ### Creating Database:

# %%
#Creating the database
mydb=client.db3103

# %%
#Creating the database
mydb2=client['db31032']

# %% [markdown]
# ### Creating Collection:

# %%
# Creating Collection
collection = mydb.coll3103

# %%
collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'db3103'), 'coll3103')

# %%
# Creating Collection
collection2=mydb['coll31032']

# %%
collection2
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'db31032'), 'coll31032')

# %% [markdown]
# ### Inserting Documents:

# %%
record={
    'fn':'krish',
    'ln':'a',
    'dept':'ML'
}

collection.insert_one(record)

# %%
record2={
    'fn':'krish',
    'ln':'a',
    'dept':'ML'
}

collection2.insert_one(record)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### Other way of  inserting documents:

# %%
mydb.coll3103.insert_one({'check':'checker','test':'tester'})

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mydb['coll3103'].insert_one({'check':'checker4','test':'tester4'})

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **IMP:**
#
# `mydb.coll411.insert_one(record)`
#
# We can insert document into the collection with the above statment, if the collection, mentioned in the above query is not present in te db, it will create that collection and then insert the document(s) into the collection.
# Same is also applicable for inerting multiple documents.
#
# `mydb.coll411.insert_Many(records)`

# %%
mydb.coll411.insert_one({'check':'checker1','test':'tester1'})

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
records=[
{
    'fn':'krish',
    'ln':'a',
    'dept':'ML'},
{   'fn':'krish1',
    'ln':'a1',
    'dept':'ML1'},
{   'fn':'krish2',
    'ln':'a2', 
    'dept':'ML2'}
]

collection.insert_many(records)

# %%
records2=[
{
    'fn':'krish',
    'ln':'a',
    'dept':'ML'},
{   'fn':'krish1',
    'ln':'a1',
    'dept':'ML1'},
{   'fn':'krish2',
    'ln':'a2', 
    'dept':'ML2'}
]

collection2.insert_many(records)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
records3=[
{
    'fn':'krish',
    'ln':'a',
    'dept':'ML'},
{   'fn':'krish1',
    'ln':'a1',
    'dept':'ML1'},
{   'fn':'krish2',
    'ln':'a2', 
    'dept':'ML2'}
]

mydb.coll789.insert_many(records3)
#collection:coll789 is not present in the database:db3103 (mydb=client.db3103)

# %% [markdown]
# collection:`coll789` is not present in the database:`db3103` (mydb=client.db3103)
#
# We can insert document into the collection with the statment - `mydb.coll789.insert_many(records3)`
#
# if the collection, mentioned in the above query is not present in the db, it will create that collection and then insert the document(s) into the collection.
#
# ![image.png](attachment:image.png)
