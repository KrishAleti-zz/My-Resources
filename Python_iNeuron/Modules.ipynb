# %%
import math

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
from math import sqrt

# %%
sqrt(9)
# Out:
# 3.0

# %%
from math import sqrt,pi

# %%
pi
# Out:
# 3.141592653589793

# %%
from math import * #we can import all the functions of math module using *

# %%
sin(0)
# Out:
# 0.0

# %%
sqrt(16)
# Out:
# 4.0

# %%
pi
# Out:
# 3.141592653589793

# %%
pwd()
# Out:
# 'D:\\Edu\\Data Science_iNeuron\\Live Class\\Live Class Notes\\Python'

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %%
import test
# Out:
# Learning modules concept

# %%
import test #If I am importing for the 2nd time, I'm not able to get the data

# %% [markdown]
# ### If I am importing for the 2nd time, I'm not able to get the data.
# So, to overcome this issue we import imp module and its reload funtion.

# %%
import imp

# %%
imp.reload(test)
# Out:
# Learning modules concept
# <module 'test' from 'D:\\Edu\\Data Science_iNeuron\\Live Class\\Live Class Notes\\Python\\test.py'>

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
import addition

# %%
addition.additionfn(4,5)
# Out:
# 9

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import test2 #if we import the module like this we can access all the functions in that modules by calling as module.fun()
from test2 import mu #if we import the module like this we can access only the mu function.
from test2 import * 
#if we import the module like this we can access all the functions by directly calling the functions.

# %%
import test2 #if we import the module like this we can access all the functions in that modules by calling as module.fun()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
test2.power(2,3)
# Out:
# 8

# %%
from test2 import mu #if we import the module like this we can access only the mu function.

# %%
mu(2,5)
# Out:
# 10

# %%
from test2 import * 
#if we import the module like this we can access all the functions by directly calling the functions.

# %%
add2(5,5)
# Out:
# 10

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import test11

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
test11.msg()
# Out:
# 'Learning'

# %%
test11.get_course()
# Out:
# ['py', 'ml', 'dl']

# %%
from test11 import msg

# %%
msg()
# Out:
# 'Learning'

# %% [markdown]
# ### Task:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Solution:

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
